# %% [markdown]
# <a href="https://colab.research.google.com/github/sahar-mariam/marvel-level-1-report/blob/main/knn1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris, load_breast_cancer, load_wine

# Load the datasets
iris = load_iris()
breast_cancer = load_breast_cancer()
wine = load_wine()

# Create a list of datasets
datasets = [iris, breast_cancer, wine]

# Create a list of labels
labels = ['iris', 'breast_cancer', 'wine']

# Create a list of K values
k_values = [1, 3, 5, 7, 9]

# Iterate over the datasets
for dataset, label in zip(datasets, labels):
    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(dataset.data, dataset.target, test_size=0.2, random_state=42)

    # Iterate over the K values
    for k in k_values:
        # Create a KNN classifier
        knn = KNeighborsClassifier(n_neighbors=k)

        # Fit the classifier to the training data
        knn.fit(X_train, y_train)

        # Predict the labels of the test data
        y_pred = knn.predict(X_test)

        # Calculate the accuracy of the classifier
        accuracy = knn.score(X_test, y_test)

        # Print the accuracy
        print(f"Accuracy for {label} dataset with K={k}: {accuracy:.2f}")
# Out:
# Accuracy for iris dataset with K=1: 1.00
# Accuracy for iris dataset with K=3: 1.00
# Accuracy for iris dataset with K=5: 1.00
# Accuracy for iris dataset with K=7: 0.97
# Accuracy for iris dataset with K=9: 1.00
# Accuracy for breast_cancer dataset with K=1: 0.93
# Accuracy for breast_cancer dataset with K=3: 0.93
# Accuracy for breast_cancer dataset with K=5: 0.96
# Accuracy for breast_cancer dataset with K=7: 0.96
# Accuracy for breast_cancer dataset with K=9: 0.96
# Accuracy for wine dataset with K=1: 0.78
# Accuracy for wine dataset with K=3: 0.81
# Accuracy for wine dataset with K=5: 0.72
# Accuracy for wine dataset with K=7: 0.69
# Accuracy for wine dataset with K=9: 0.72

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris, load_breast_cancer, load_wine

# Load the datasets
iris = load_iris()
breast_cancer = load_breast_cancer()
wine = load_wine()

# Create a list of datasets
datasets = [iris, breast_cancer, wine]

# Create a list of labels
labels = ['iris', 'breast_cancer', 'wine']

# Create a list of K values
k_values = [1, 3, 5, 7, 9]

# Iterate over the datasets
for dataset, label in zip(datasets, labels):
    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(dataset.data, dataset.target, test_size=0.2, random_state=42)

    # Create a list to store the accuracies
    accuracies = []

    # Iterate over the K values
    for k in k_values:
        # Create a KNN classifier
        knn = KNeighborsClassifier(n_neighbors=k)

        # Fit the classifier to the training data
        knn.fit(X_train, y_train)

        # Predict the labels of the test data
        y_pred = knn.predict(X_test)

        # Calculate the accuracy of the classifier
        accuracy = knn.score(X_test, y_test)

        # Store the accuracy
        accuracies.append(accuracy)

    # Plot the accuracies
    plt.plot(k_values, accuracies)
    plt.xlabel('K')
    plt.ylabel('Accuracy')
    plt.title(f'Accuracy for {label} dataset')
    plt.show()
